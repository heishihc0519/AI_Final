# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn import grid_search
import pandas as pd

# Train data
df = pd.read_csv('LargeTrain.csv')

# columns
columns =  list(df.columns.values)

# data and target
X = df[ columns[0:-1] ]
Y = df['Class']

# Cross-validation
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.4, random_state=0)

# create model
clf = Lasso(alpha=0.01)

# feature selection
sfm = SelectFromModel(clf, threshold=0.25)

# fitting model
sfm.fit(X_train,y_train)

# feature output
n_features = sfm.transform(X_train).shape[1]
print n_features

# print feature names
scaler = StandardScaler()
X1 = scaler.fit_transform(X_train)
names = columns
lasso = Lasso(alpha=0.01, positive=True)
lasso.fit(X1, y_train)
print (sorted(zip(map(lambda x: round(x, 10),lasso.coef_),names),reverse=True))
# Out:
# 2
# [(1.628422308, 'dc_por'), (1.0440897246, 'section_names_header'), (0.9573029548, 'ent_q_diff_diffs_10'), (0.9265442858, 'Img9'), (0.4197798635, 'ent_q_diff_diffs_2_min'), (0.4174902225, 'Img22'), (0.3829979534, 'Img37'), (0.3743367873, 'db3_NdNt'), (0.3668450186, '__setusermatherr'), (0.3494346429, 'Img48'), (0.3481049792, 'string_ratio'), (0.3430814926, 'ent_q_diff_block_3_18'), (0.3418673202, 'ent_q_diff_diffs_1_min'), (0.3345124321, 'ent_q_diff_diffs_8'), (0.3323285291, '.text_por'), (0.3090250846, 'ent_p_13'), (0.2834196149, 'popf'), (0.27213976, 'ent_q_diff_diffs_0_min'), (0.2657750991, 'string_len_counts_2'), (0.2413434482, 'dd5_all'), (0.210655852, 'ent_q_diff_block_2_15'), (0.2091296709, 'ent_q_diff_diffs_0_mean'), (0.200403976, 'Unknown_Sections_por'), (0.1979152971, 'ent_q_diff_block_3_16'), (0.1933141826, 'ent_q_diff_diffs_7'), (0.1897576554, 'ent_q_diff_block_2_4'), (0.1822006299, 'ent_q_diff_block_3_15'), (0.174295157, 'ent_q_diff_block_2_14'), (0.1681846154, 'ent_q_diff_block_0_19'), (0.1658312401, 'asm_commands_imul'), (0.1629637801, 'ent_q_diff_block_1_14'), (0.1559849416, 'ent_q_diff_block_1_0'), (0.1497852589, 'ent_p_diffs_10'), (0.1470604063, 'SetServiceStatus'), (0.1440950796, 'ent_q_diff_diffs_0_var'), (0.1415253843, 'ent_p_diffs_2'), (0.1353691603, 'ent_p_diffs_15'), (0.1249956628, 'ent_p_diffs_16'), (0.1148015666, 'CreateToolhelp32Snapshot'), (0.1087535165, 'EVENT_SINK_Release'), (0.1086066939, 'dd_rdata'), (0.1049389484, 'db'), (0.0980085544, 'ent_q_diff_block_3_5'), (0.09185975, 'ent_p_4'), (0.0917109075, 'ent_q_diff_block_3_1'), (0.0890037258, 'ent_q_diff_diffs_6'), (0.0838995711, 'dd6_all'), (0.0834813109, 'ent_q_diff_block_2_18'), (0.0822688124, 'ent_q_diff_block_3_17'), (0.0777139481, 'ent_q_diff_block_3_3'), (0.0725513416, 'TB_cc'), (0.0699993938, 'ent_q_diff_block_2_17'), (0.0610306539, 'InternetOpenUrlA'), (0.0608344278, 'loope'), (0.0607154868, 'MoveFileExA'), (0.0581276159, 'ent_p_diffs_6'), (0.0554698381, 'ent_q_diff_block_3_0'), (0.0554110247, 'ent_p_diffs_0'), (0.0547623264, '__vbaEnd'), (0.0544414652, 'asm_commands_cld'), (0.0490280709, 'Unknown_Sections_lines'), (0.0489065805, 'ent_q_diff_block_0_13'), (0.0483143631, 'ent_q_diff_block_0_18'), (0.0481405298, 'wvsprintfA'), (0.0471370316, 'ent_q_diff_block_2_13'), (0.0464887971, 'dw_por'), (0.0422154472, 'ent_q_diff_block_3_6'), (0.0415578458, 'FindWindowA'), (0.0408479165, 'ImageList_DragShowNolock'), (0.0404326252, 'ent_q_diff_block_1_15'), (0.0384986817, 'string_len_counts_6000_15000'), (0.0377961016, 'ent_q_diff_block_3_20'), (0.0374628871, 'Img1'), (0.0353779687, 'ent_q_diff_block_2_6'), (0.0331833518, 'URLDownloadToFileA'), (0.0330932989, 'DisableThreadLibraryCalls'), (0.0324596947, 'GetForegroundWindow'), (0.0321592278, 'OpenProcessToken'), (0.0318374322, 'string_len_counts_600_900'), (0.0314875153, 'ent_q_diffs_17'), (0.0309763052, 'IsValidLocale'), (0.030718047, 'System32'), (0.0280381782, 'misc1_sp-analysisfailed'), (0.0277525497, 'asm_commands_sbb'), (0.0271348175, 'ShellExecuteW'), (0.0258959645, '.data_por'), (0.0248902303, 'Entropy'), (0.0237465539, 'SafeArrayPtrOfIndex'), (0.0230133494, 'lstrcpyA'), (0.0227811833, 'ent_q_diff_block_0_4'), (0.022596621, 'GetDateFormatA'), (0.0223798051, 'SHGetSpecialFolderPathA'), (0.021568284, 'ent_p_diffs_17'), (0.0205096161, 'ClosePrinter'), (0.0200971917, 'GetUserDefaultLangID'), (0.0176321294, 'GlobalGetAtomNameA'), (0.0174907029, 'imul'), (0.0173055951, 'ent_q_diff_block_0_1'), (0.017226187, 'GetOpenFileNameA'), (0.0171524645, 'gs'), (0.0170194748, 'ent_q_diff_block_1_16'), (0.0170063541, 'CreateRemoteThread'), (0.0168214144, 'VariantChangeTypeEx'), (0.0144717654, 'SetPixel'), (0.0144465336, '.tls_por'), (0.0141634923, 'StartServiceA'), (0.0135798568, 'ent_q_diff_block_2_2'), (0.0112998775, 'CHUNK'), (0.0109699068, 'CreateServiceA'), (0.0101501216, 'GetStartupInfoA'), (0.0099179134, 'asm_commands_sidt'), (0.0099025551, 'ent_p_diffs_12'), (0.0095544977, '__vbaI2Var'), (0.0089955525, 'ent_ ...
